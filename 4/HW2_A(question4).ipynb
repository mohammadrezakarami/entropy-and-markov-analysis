# %% [markdown]
# #HW2_part A (Question 4)
# ## Shahrzad Shivaei

# %%
##part2
#We aim to calculate the entropy E of the distribution, where Z is
 a normalizing factor
import math
s = 0
for n in range(0,100000):
  s += math.exp(-n**2)
E = 0
for n in range(0,100000):

  E += (math.exp(-n**2)*n*n)

print(s)
print(math.log(s)+(1/s)*(E))
# Out:
# 1.3863186024133263
# 0.6456653446139602

# %%
##part3
#here we calculate the summation term which does not have a closed-form solution and requires numerical evaluation
import math

s = 0
z = (math.pi**4)/90
for i in range(1,10000):
  s+= (n**(-4))*math.log(n)

print(4*s/z+math.log(z))
# Out:
# 0.07910987306733964

# %%
##part5
# These sums are related to special functions like the Hurwitz zeta function, and they do not have simple closed-form expressions for entropy so we use the numerical solution:
import math
E1 = 0
E2 = 0
s1 = 0
s2 = 0
for n in range(0,1000000):
  s1 += (1+n**2)**(-1)
  s2 += (1+n**2)**(-2)

for n in range(0,1000000):
  n1 = ((1 + n**2)**(-1)) / s1
  n2 = ((1 + n**2)**(-2)) / s2
  E1 += n1*math.log(n1)
  E2 += n2*math.log(n2)
print('Z1 =', s1)
print('Z2 =', s2)
print('Entropy for k = 1 is', -E1)
print('Entropy for k = 2 is', -E2)
# Out:
# Z1 = 2.076673047468177
# Z2 = 1.306836975422631
# Entropy for k = 1 is 1.7742596267503163
# Entropy for k = 2 is 0.7009278176290031
